# %%
from dask.distributed import Client
client = Client(scheduler_file='/home/jcosme/proj/dask-cuda-app/cluster_settings/scheduler-file')
client #this will display the URL for accessign the dashboard

#your dask operations here
# Out:
# <Client: 'tcp://192.168.0.142:8786' processes=8 threads=48, memory=125.65 GiB>

# %%
#your dask operations here


client.close()
del client
